# %% [markdown]
# <a href="https://colab.research.google.com/github/JNarimatsu/modelo_prenvendo_voos_ONE/blob/main/Modelo_atraso_voo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import yellowbrick

# %% [markdown]
# ## Leitura dos dados

# %%
url = 'https://raw.githubusercontent.com/JNarimatsu/modelo_prenvendo_voos_ONE/refs/heads/main/flights.csv'

# %%
pd.read_csv(url)
